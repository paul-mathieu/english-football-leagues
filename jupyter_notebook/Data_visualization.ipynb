# %%
import pandas as pd

# %%
import statistics

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_file_name = 'winner of league-one.csv' #please put the name of the csv file you want to read

# %%
data = pd.read_csv(csv_file_name, index_col=[0],sep=',', encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-ceabc5a9aa19> in <module>
# ----> 1 data = pd.read_csv(csv_file_name, index_col=[0],sep=',', encoding="utf-8")
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1872         if kwds.get("compression") is None and encoding:
#    1873             if isinstance(src, str):
# -> 1874                 src = open(src, "rb")
#    1875                 self.handles.append(src)
#    1876
#
# FileNotFoundError: [Errno 2] No such file or directory: 'winner of league-one.csv'

# %%
data.iloc[:49] # we display the first 50 rows
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7feb982e6533> in <module>
# ----> 1 data.iloc[:49] # we display the first 50 rows
#
# NameError: name 'data' is not defined

# %%
table = pd.read_csv(csv_file_name, sep=',', encoding="utf-8")

# %%
col_list = ["id"] #to add an id col

# %%
for col in data.columns:  # we set the table col name
    col_list.append(col)

# %%
table.columns = col_list

# %%
print(table.head(5))

# %%
#transferMarkt
csv_file_name = 'player_market_value_of_arsenal_in_2019.csv' #please put the name of the csv file you want to read

# %%
data = pd.read_csv(csv_file_name, index_col=[0],sep=',', encoding="utf-8")

# %%
data.iloc[:49] # we display the first 50 rows
# Out:
#     player_id                player_name player_contract_expires  \
# 0       72476                 Bernd Leno              30.06.2023
# 1      111873          Emiliano Martínez              30.06.2022
# 2      220491                 Matt Macey              30.06.2020
# 3       34322                   Sokratis              30.06.2021
# 4       88590           Shkodran Mustafi              30.06.2021
# 5       46741                 David Luiz              30.06.2021
# 6      253341                Rob Holding              30.06.2023
# 7      210178                 Pablo Marí              30.06.2020
# 8      300716             Kieran Tierney              30.06.2024
# 9      433177                Bukayo Saka              30.06.2021
# 10      94005             Sead Kolasinac              30.06.2022
# 11     191217            Héctor Bellerín              30.06.2023
# 12     285845     Ainsley Maitland-Niles              30.06.2023
# 13     215118             Calum Chambers              30.06.2022
# 14     112988              Cédric Soares              31.05.2020
# 15     318077             Lucas Torreira              30.06.2023
# 16     111455               Granit Xhaka              30.06.2023
# 17     465830           Mattéo Guendouzi              30.06.2022
# 18     319745              Dani Ceballos              30.06.2020
# 19     340329                Joe Willock                       -
# 20      35664                 Mesut Özil              30.06.2021
# 21     343052               Nicolas Pépé              30.06.2024
# 22     340325               Reiss Nelson              30.06.2023
# 23      58864  Pierre-Emerick Aubameyang              30.06.2021
# 24      93720        Alexandre Lacazette              30.06.2022
# 25     655488         Gabriel Martinelli              30.06.2024
# 26     340324              Eddie Nketiah              30.06.2022
#
#     player_market_value_€
# 0              28000000.0
# 1               2800000.0
# 2                250000.0
# 3              14500000.0
# 4              12000000.0
# 5              12000000.0
# 6               9500000.0
# 7               4800000.0
# 8              20000000.0
# 9              20000000.0
# 10             16000000.0
# 11             32000000.0
# 12             14500000.0
# 13             14500000.0
# 14              8000000.0
# 15             36000000.0
# 16             24000000.0
# 17             40500000.0
# 18             32000000.0
# 19             16000000.0
# 20             17500000.0
# 21             52000000.0
# 22             12500000.0
# 23             56000000.0
# 24             48000000.0
# 25             25000000.0
# 26             11000000.0

# %%
table = pd.read_csv(csv_file_name, index_col=[0], sep=',', encoding="utf-8")

# %%
player_market_value_E = table["player_market_value_€"]

# %%
#Analysing data
print("min : ", min(player_market_value_E),"€")
print("max : ", max(player_market_value_E),"€")
print("mean : ", statistics.mean(player_market_value_E),"€")
# Out:
# min :  250000.0 €
# max :  56000000.0 €
# mean :  21457407.407407407 €

# %%
#This next line makes our charts show up in the notebook
# %matplotlib inline

table = pd.read_csv(csv_file_name)
table.head()
#Create bar chart 
plt.barh(np.arange(1,28),width=table['player_market_value_€'], align='center')
plt.title(csv_file_name[:len(csv_file_name)-4])
#plt.xticks(np.arange(1,27), table['player_name'], rotation=90)
plt.yticks(np.arange(1,28), table['player_name'])
#Give the x and y axes a title
plt.xlabel("Players")
plt.ylabel("Market values")
#show the bar chart

axes = plt.gca()
axes.set_xlim([min(player_market_value_E)-100,max(player_market_value_E)+100])
plt.show()

# %%
#This next line makes our charts show up in the notebook
# %matplotlib inline

table = pd.read_csv(csv_file_name)
table.head()
#Create bar chart 
plt.bar(x=np.arange(1,28),height=table['player_market_value_€'])
plt.title(csv_file_name[:len(csv_file_name)-4])
plt.xticks(np.arange(1,28), table['player_name'], rotation=90)
#Give the x and y axes a title
plt.xlabel("Players")
plt.ylabel("Market values €")
#show the bar chart

plt.show()

# %%
#This next line makes our charts show up in the notebook
# %matplotlib inline

table = pd.read_csv(csv_file_name)
table.head()

#Create bar chart
plt.figure(figsize=(20, 3))  # width:20, height:3, change the size of the chart
plt.bar(x=np.arange(1,28),height=table['player_market_value_€'])
plt.title(csv_file_name[:len(csv_file_name)-4])
plt.xticks(np.arange(1,28), table['player_name'], rotation=30, ha='right')

#Give the x and y axes a title
plt.xlabel("Players")
plt.ylabel("Market values €")

#Display the mean line of player market values
plt.axhline(statistics.mean(player_market_value_E), color='red', linewidth=2, label="average of player market values")
plt.legend(loc='upper left')
#show the bar chart
plt.show()
